# %%
import requests
from PIL import Image
from io import BytesIO

# %%
def get_card(card_name):
    SCRYFALL_API = 'https://api.scryfall.com'
    endpoint = '/cards/named'
    
    url = SCRYFALL_API+endpoint
    
    parameters = {'exact': card_name, 'format': 'image'}
    
    result = requests.get(url, params=parameters)
    
    return result

# %%
resp = get_card('Murder')

# %%
i = Image.open(BytesIO(resp.content))

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=672x936 at 0x10A19BE20>
